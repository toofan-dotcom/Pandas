# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40,50,60,70])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s1=pd.Series([11,21,31,41,51,61,71],index=['a','b','c','d','e','f','g'])

# %%
s1
# Out:
# a     11
# b     21
# c     31
#  d    41
# e     51
# f     61
# g     71
# dtype: int64

# %%
s1['b']
# Out:
# np.int64(21)

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)
