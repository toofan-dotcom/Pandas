# %%
import pandas as pd

# %%
# You can now run the same analysis I gave earlier:

# Count Movies vs TV Shows

# Top genres

# Top actors

# Trend over years

# %%
df=pd.read_csv("mock_netflix_data.csv")

# %%
df
# Out:
#    show_id     type      title    director              cast         country  \
# 0       s1    Movie    Title 1  Director A  Actor A, Actor D             NaN
# 1       s2    Movie    Title 2         NaN  Actor A, Actor B             NaN
# 2       s3    Movie    Title 3  Director B  Actor A, Actor D           India
# 3       s4    Movie    Title 4  Director B  Actor E, Actor F          Canada
# 4       s5    Movie    Title 5         NaN  Actor E, Actor F   United States
# ..     ...      ...        ...         ...               ...             ...
# 95     s96  TV Show   Title 96         NaN  Actor E, Actor F   United States
# 96     s97    Movie   Title 97  Director C  Actor E, Actor F  United Kingdom
# 97     s98  TV Show   Title 98  Director C               NaN             NaN
# 98     s99  TV Show   Title 99  Director B  Actor C, Actor D  United Kingdom
# 99    s100  TV Show  Title 100  Director B               NaN  United Kingdom
#
# ...

# %%
df.groupby("type").size()
# Out:
# type
# Movie      52
# TV Show    48
# dtype: int64

# %%
df['type'].value_counts()
# Out:
# type
# Movie      52
# TV Show    48
# Name: count, dtype: int64

# %%
df.dropna()
# Out:
#    show_id     type     title    director              cast         country  \
# 3       s4    Movie   Title 4  Director B  Actor E, Actor F          Canada
# 12     s13    Movie  Title 13  Director C  Actor E, Actor F          Canada
# 13     s14    Movie  Title 14  Director C  Actor A, Actor B          Canada
# 14     s15  TV Show  Title 15  Director B  Actor C, Actor D   United States
# 22     s23    Movie  Title 23  Director A  Actor A, Actor B          Canada
# 24     s25  TV Show  Title 25  Director C  Actor A, Actor B  United Kingdom
# 26     s27    Movie  Title 27  Director C  Actor A, Actor B           India
# 27     s28  TV Show  Title 28  Director A  Actor E, Actor F           India
# 31     s32  TV Show  Title 32  Director B  Actor E, Actor F          Canada
# 33     s34  TV Show  Title 34  Director A  Actor E, Actor F   United States
# 37     s38    Movie  Title 38  Director B  Actor A, Actor D           India
# ...

# %%
df.groupby("listed_in").size().sort_values(ascending=False)
# Out:
# listed_in
# Children & Family Movies, Comedies    26
# Comedies, Dramas                      20
# Documentaries                         14
# Action & Adventure                    13
# Dramas, International Movies          11
# dtype: int64

# %%
df['cast'].value_counts().sort_values(ascending=False)
# Out:
# cast
# Actor A, Actor B    24
# Actor E, Actor F    24
# Actor C, Actor D    22
# Actor A, Actor D    13
# Name: count, dtype: int64

# %%
from collections import Counter

print(Counter(', '.join(df['cast'].fillna('')).split(', ')).most_common(10))
# Out:
# [('Actor A', 37), ('Actor D', 35), ('Actor B', 24), ('Actor E', 24), ('Actor F', 24), ('Actor C', 22), ('', 17)]

# %%
df['cast'].dropna().str.split(', ').explode().value_counts()
# Out:
# cast
# Actor A    37
# Actor D    35
# Actor B    24
# Actor E    24
# Actor F    24
# Actor C    22
# Name: count, dtype: int64
