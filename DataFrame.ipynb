# %%
import pandas as pd

# %%
import pandas as pd

data = [
    ["Alice", 25],
    ["Bob", 30],
    ["Charlie", 35]
]

df = pd.DataFrame(data, columns=["Name", "Age"])
df
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
data1={
    "name":["Abhishek","Ranjan","Choubey"],
     "age":[22,23,24]
      
}
df = pd.DataFrame(data1)
df
# Out:
#        name  age
# 0  Abhishek   22
# 1    Ranjan   23
# 2   Choubey   24

# %%
import numpy as np

# %%
arr=np.array([[1,2],[5,6]])
df=pd.DataFrame(arr,columns=["col1","col2"])
df
# Out:
#    col1  col2
# 0     1     2
# 1     5     6

# %%
df=pd.read_excel("data.xlsx")
df
# Out:
#        Name   School  Marks
# 0  Abhishek      PCS     98
# 1    Ranjan    ASPCS     97
# 2   Choubey  ASJMPCS     96
# 3  Divyansh      SVM     65
# 4     Aryan      LLS     92
# 5     Verma      DAV     99
# 6  Premdeep      DPS     88

# %%
df=pd.read_json("data.json")
df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30    London
# 2  Charlie   35     Paris
# 3    David   28    Berlin
# 4      Eva   22     Tokyo
