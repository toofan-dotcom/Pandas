# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_excel("data.xlsx")
df
# Out:
#                 Actor             Film            Genre  Year  \
# 0      Shah Rukh Khan          Pathaan           Action  2023
# 1          Aamir Khan           Dangal     Sports Drama  2016
# 2         Salman Khan  Tiger Zinda Hai           Action  2017
# 3       Ranbir Kapoor           Animal     Action Drama  2023
# 4       Ranveer Singh           Simmba           Action  2018
# 5      Hrithik Roshan              War  Action Thriller  2019
# 6        Akshay Kumar       Good Newwz     Comedy Drama  2019
# 7          Ajay Devgn          Tanhaji       Historical  2020
# 8       Vicky Kaushal              Uri              War  2019
# 9  Ayushmann Khurrana       Dream Girl           Comedy  2019
#
#    Box Office (Cr INR)  IMDb Rating
# 0                 1050          5.9
# 1                 2024          8.4
# 2                  565          6.0
# 3                  915          7.1
# 4                  400          5.4
# 5                  475          6.5
# ...

# %%
df["Actor"][1]
# Out:
# 'Aamir Khan'

# %%
df[["Actor","Film"]]
# Out:
#                 Actor             Film
# 0      Shah Rukh Khan          Pathaan
# 1          Aamir Khan           Dangal
# 2         Salman Khan  Tiger Zinda Hai
# 3       Ranbir Kapoor           Animal
# 4       Ranveer Singh           Simmba
# 5      Hrithik Roshan              War
# 6        Akshay Kumar       Good Newwz
# 7          Ajay Devgn          Tanhaji
# 8       Vicky Kaushal              Uri
# 9  Ayushmann Khurrana       Dream Girl

# %%
df.iloc[0]
# Out:
# Actor                  Shah Rukh Khan
# Film                          Pathaan
# Genre                          Action
# Year                             2023
# Box Office (Cr INR)              1050
# IMDb Rating                       5.9
# Name: 0, dtype: object

# %%
df.loc[8,"Film"]
# Out:
# 'Uri'

# %%
df.loc[0:2,["Actor","Film"]]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1      Aamir Khan           Dangal
# 2     Salman Khan  Tiger Zinda Hai

# %%
df.at[1,"Actor"]
# Out:
# 'Aamir Khan'

# %%
df.iat[1,3]
# Out:
# np.int64(2016)

# %%
cond=df["IMDb Rating"]>7

# %%
df[cond]["Actor"]
# Out:
# 1       Aamir Khan
# 3    Ranbir Kapoor
# 7       Ajay Devgn
# 8    Vicky Kaushal
# Name: Actor, dtype: object

# %%
cond2=df["Year"]>2020

# %%
df[cond&cond2]
# Out:
#            Actor    Film         Genre  Year  Box Office (Cr INR)  IMDb Rating
# 3  Ranbir Kapoor  Animal  Action Drama  2023                  915          7.1

# %%
df[cond | cond2]
# Out:
#             Actor     Film         Genre  Year  Box Office (Cr INR)  \
# 0  Shah Rukh Khan  Pathaan        Action  2023                 1050
# 1      Aamir Khan   Dangal  Sports Drama  2016                 2024
# 3   Ranbir Kapoor   Animal  Action Drama  2023                  915
# 7      Ajay Devgn  Tanhaji    Historical  2020                  367
# 8   Vicky Kaushal      Uri           War  2019                  342
#
#    IMDb Rating
# 0          5.9
# 1          8.4
# 3          7.1
# 7          7.5
# 8          8.2

# %%
df.query("Year>2019")
# Out:
#             Actor     Film         Genre  Year  Box Office (Cr INR)  \
# 0  Shah Rukh Khan  Pathaan        Action  2023                 1050
# 3   Ranbir Kapoor   Animal  Action Drama  2023                  915
# 7      Ajay Devgn  Tanhaji    Historical  2020                  367
#
#    IMDb Rating
# 0          5.9
# 3          7.1
# 7          7.5
